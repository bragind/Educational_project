# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
# в связи с ограниченным объемом памяти на ноутбуке загружаю 10000 строк датасета
df = pd.read_csv('E:/Studies/Project/cv_analysis_python/dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
#выводим 5 первых строк
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %%
#выводим 5 последних строк
df.tail()
# Out:
#                                      Пол, возраст          ЗП  \
# 995  Женщина ,  22 года , родилась 25 ноября 1996  80000 руб.
# 996   Мужчина ,  35 лет , родился 11 декабря 1983  80000 руб.
# 997    Мужчина ,  29 лет , родился 18 января 1990  25000 руб.
# 998   Мужчина ,  37 лет , родился 25 февраля 1982  50000 руб.
# 999    Мужчина ,  30 лет , родился 10 апреля 1989  35000 руб.
#
#                              Ищет работу на должность:  \
# 995                             Администратор проектов
# 996            Начальник IT подразделения, IT директор
# 997                   Специалист технической поддержки
# 998                            системный администратор
# 999  Сервисный инженер , электромонтер, мастер по р...
#
#                           Город, переезд, командировки  \
# 995  Москва ,  м. Планерная , не готова к переезду ...
# 996  Санкт-Петербург ,  м. Пионерская , готов к пер...
# 997  Воронеж , не готов к переезду , не готов к ком...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
# Функция для извлечения уровня образования
def extract_education_level(row):
    # Разделяем строку по пробелам и берем первые два элемента
    education_level = row["Образование и ВУЗ"].split()[:2]
    
    # Преобразуем в строчную форму и объединяем обратно в одну строку
    return " ".join([word.lower() for word in education_level])

# Применяем функцию к каждому значению в колонке "Образование и ВУЗ"
df["Образование"] = df.apply(extract_education_level, axis=1)

# Проверяем уникальные значения в новой колонке
unique_values = df["Образование"].unique()
print("Уникальные значения:", unique_values)

# Удаляем старый признак "Образование и ВУЗ"
df.drop(columns=["Образование и ВУЗ"], inplace=True)

# Смотрим итоговый датафрейм
print("\nИтоговый датафрейм:")
print(df)
# Out:
# Уникальные значения: ['неоконченное высшее' 'высшее образование' 'среднее специальное'
#  'среднее образование']
#
# Итоговый датафрейм:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
# ...

# %%
value_counts = df['Образование'].value_counts()

print(value_counts)
# Out:
# Образование
# высшее образование     33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее образование      559
# Name: count, dtype: int64

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь

# Разбиваем каждую строку на части
parts = df["Пол, возраст"].str.split(" , ")

# Создадим новые столбцы
df['Пол'] = parts.str[0].replace({'Мужчина': 'М', 'Женщина': 'Ж'})

# Очищаем возраст от лишних символов и приводим к числу
age_parts = parts.str[1].str.strip().str.replace(r'\D+', '', regex=True).astype(int)
df['Возраст'] = age_parts

# Убираем исходный столбец
df.drop(columns="Пол, возраст", inplace=True)

# Вывод результата
print(df)
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                             Город, переезд, командировки  \
# 0      Советск (Калининградская область) , не готов к...
# ...

# %%
value_counts_percent = df['Пол'].value_counts(normalize=True) * 100

print(value_counts_percent)
# Out:
# Пол
# М    80.929287
# Ж    19.070713
# Name: proportion, dtype: float64

# %%
#чему равен средний возраст соискателей
average_value = df['Возраст'].mean()

print(f'Среднее значение в столбце "Возраст": {average_value:.2f}')
# Out:
# Среднее значение в столбце "Возраст": 32.20

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь



# Функция для извлечения общего опыта работы в месяцах
import re
def extract_total_months(row):
    if pd.isna(row["Опыт работы"]) or row["Опыт работы"] == "Не указано":
        return np.nan
    
    # Используем регулярное выражение для поиска чисел
    pattern = r'\d+'
    numbers = re.findall(pattern, row["Опыт работы"])
    
    if not numbers:
        return np.nan
    
    # Первый элемент - годы, второй - месяцы
    years = int(numbers[0]) if len(numbers) > 0 else 0
    months = int(numbers[1]) if len(numbers) > 1 else 0
    
    total_months = years * 12 + months
    return total_months

# Применяем функцию к каждому значению в колонке "Опыт работы"
df["Опыт работы (месяцы)"] = df.apply(extract_total_months, axis=1)

# Проверяем уникальные значения в новой колонке
unique_values = df["Опыт работы (месяцы)"].unique()
print("Уникальные значения:", unique_values)

# Удаляем старый признак "Опыт работы"
df.drop(columns=["Опыт работы"], inplace=True)

# Смотрим итоговый датафрейм
print("\nИтоговый датафрейм:")
print(df)
# Out:
# Уникальные значения: [ 202.  233.  123.  225.   67.  117.  273.   47.  105.  198.  137.  510.
#   162.   83.   17.   46.  109.  189.  114.  143.   59.   68.  160.  138.
#   147.  111.  237.  178.  112.   98.  101.   64.   61.   87.   20.  268.
#    63.  194.  126.  325.  141.   74.   30.   56.  207.   38.  303. 2107.
#    65.  149.  206.  350.   73.   33.   92.   86.   80.   35.   nan  174.
#    13.   93. 2378. 2078.  115.   29.  154.  128.   79.   23.  107.  200.
#   157.  186.  172. 2138.  125.   14.  102.  209.  148.   25.  104.   51.
#    78.  132.  165.  170.  219.  133.   21.   99. 2326.  296.  130.   66.
#    42.   62. 2343.  173.   70. 2470.  295.   40.  153. 2127.  122. 2089.
#    89.  175.  185.   28. 2197.  507.  127. 2054. 2137.   69. 2150.   19.
#    41. 2125.  267.  166.   15.  135. 2063.  360. 2030.   77.   85.  227.
#    50.  145.  218.   45.  134.   75.  221.  199.  142.   54.  255.   81.
#   254.  121.  179.  212.   90.   88.   22.  188.   31.   55.  177.  183.
# ...

# %%
median_value = df['Опыт работы (месяцы)'].median()

print(f'Медиана в столбце "Опыт работы (месяцы)": {median_value}')
# Out:
# Медиана в столбце "Опыт работы (месяцы)": 112.0

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
# Список городов-миллионников
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань',
                  'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа',
                  'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']

# Функция для классификации города
def classify_city(city):
    if city == "Москва":
        return "Москва"
    elif city == "Санкт-Петербург":
        return "Санкт-Петербург"
    elif city in million_cities:
        return "город-миллионник"
    else:
        return "другие"

# Функция для определения готовности к переезду
def determine_relocation_ready(text):
    if any(substring in text.lower() for substring in ["готов", "хочу", "желание"]):
        return True
    else:
        return False

# Функция для определения готовности к командировкам
def determine_commute_ready(text):
    if "готов" in text.lower():
        return True
    else:
        return False

# Функция для преобразования строки
def transform_row(row):
    parts = row.split(",")
    
    # Определение города
    city = parts[0].strip()
    classified_city = classify_city(city)
    
    # Определение готовности к переезду
    relocation_text = ", ".join(parts[1:])
    relocation_ready = determine_relocation_ready(relocation_text)
    
    # Определение готовности к командировкам
    commute_text = ", ".join(parts[2:])
    commute_ready = determine_commute_ready(commute_text)
    
    return classified_city, relocation_ready, commute_ready

# Применение функции к каждому элементу столбца
transformed_values = df["Город, переезд, командировки"].apply(transform_row)

# Распаковка кортежей в отдельные столбцы
df[["Город", "Готовность к переезду", "Готовность к командировкам"]] = pd.DataFrame(transformed_values.tolist(), index=df.index)

# Удаление исходного столбца
del df["Город, переезд, командировки"]

# Проверка уникальных значений новых столбцов
print(df["Город"].unique())
print(df["Готовность к переезду"].unique())
print(df["Готовность к командировкам"].unique())
# Out:
# ['другие' 'Москва' 'город-миллионник' 'Санкт-Петербург']
# [ True]
# [ True False]

# %%
#Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого.
value_counts_percent = df['Город'].value_counts(normalize=True) * 100

print(value_counts_percent)
# Out:
# Город
# Москва              37.146880
# другие              35.432684
# город-миллионник    16.386555
# Санкт-Петербург     11.033882
# Name: proportion, dtype: float64

# %%
#Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? Ответ округлите до целого.
value_counts_percent = df['Готовность к переезду'].value_counts(normalize=True) * 100

print(value_counts_percent)
value_counts_percent = df['Готовность к командировкам'].value_counts(normalize=True) * 100

print(value_counts_percent)
# Out:
# Готовность к переезду
# True    100.0
# Name: proportion, dtype: float64
# Готовность к командировкам
# True     99.886018
# False     0.113982
# Name: proportion, dtype: float64

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
# Разделение строк на списки категорий
df["Занятость"] = df["Занятость"].str.split(", ")
df["График"] = df["График"].str.split(", ")

# Применение get_dummies для каждой категории
occupancy_dummies = df["Занятость"].explode().str.get_dummies(sep=", ").groupby(level=0).sum()
schedule_dummies = df["График"].explode().str.get_dummies(sep=", ").groupby(level=0).sum()

# Объединение полученных данных обратно в DataFrame
result_df = pd.concat([occupancy_dummies, schedule_dummies], axis=1)

# Удаление исходных столбцов
del df["Занятость"], df["График"]

# Добавление новых столбцов в исходный DataFrame
final_df = pd.concat([df, result_df], axis=1)

# Проверка уникальных значений новых столбцов
print(final_df)
# Out:
#                 ЗП                          Ищет работу на должность:  \
# 0       29000 руб.                            Системный администратор
# 1       40000 руб.                               Технический писатель
# 2       20000 руб.                                           Оператор
# 3      100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4      140000 руб.                  Региональный менеджер по продажам
# ...            ...                                                ...
# 44739   50000 руб.  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740   39000 руб.             Системный администратор, IT-специалист
# 44741   40000 руб.                         Аналитик данных, Математик
# 44742   20000 руб.                                   Контент-менеджер
# 44743  120000 руб.                               Руководитель проекта
#
#                          Последнее/нынешнее место работы  \
# 0                                МАОУ "СОШ № 1 г.Немана"
# ...

# %%
df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь

# Загрузка данных о курсах валют
exchange_rates = pd.read_csv("E:/Studies/Project/cv_analysis_python/ExchangeRates.csv")

# Подготовка данных о ЗП
df[["amount", "currency"]] = df["ЗП"].str.extract(r"(\d+) (\D+)\.")
df["currency"] = df["currency"].map({"руб.": "RUB", "грн.": "UAH", "USD": "USD"})

df["Обновление резюме"] = pd.to_datetime(df["Обновление резюме"], format="%Y-%m-%d %H:%M:%S")

# Приводим колонку "date" к типу datetime
exchange_rates["date"] = pd.to_datetime(exchange_rates["date"])

# Теперь выполняем слияние
df = df.merge(
    exchange_rates,
    how="left",
    left_on=["currency", "Обновление резюме"],
    right_on=["currency", "date"]
)

# Пересчёт ЗП в рубли
df["ЗП (руб.)"] = (
    df["amount"].astype(float) *
    df["close"] /
    df["proportion"]
)

# Очистка
df.drop(columns=["amount", "currency_x", "date", "proportion", "close", "currency_y"], inplace=True, errors="ignore")

# Финальный DataFrame
df.rename(columns={"currency": "Валюта"}, inplace=True)

# Печать результата
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[219], line 10
#       7 df[["amount", "currency"]] = df["ЗП"].str.extract(r"(\d+) (\D+)\.")
#       8 df["currency"] = df["currency"].map({"руб.": "RUB", "грн.": "UAH", "USD": "USD"})
# ---> 10 df["Обновление резюме"] = pd.to_datetime(df["Обновление резюме"], format="%Y-%m-%d %H:%M:%S")
#      12 # Приводим колонку "date" к типу datetime
#      13 exchange_rates["date"] = pd.to_datetime(exchange_rates["date"])
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
# ...

# %%
#Чему равна средняя медианная зарплата
median_value = df['amount'].median()

print(f'Медиана в столбце "amoun": {median_value}')

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# Выбираем столбец "Возраст"
age_series = df['Возраст']

# Строим гистограмму
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].hist(age_series, bins=5, edgecolor='black')
ax[0].set_title('Распределение возраста')
ax[0].set_xlabel('Возраст')
ax[0].set_ylabel('Количество соискателей')

# Строим boxplot
ax[1].boxplot(age_series, vert=False)
ax[1].set_title('Boxplot возраста')
ax[1].set_xlabel('Возраст')
ax[1].set_yticklabels([])

plt.tight_layout()
plt.show()

# Анализируем распределение
mode_age = age_series.mode()[0]
min_age = age_series.min()
max_age = age_series.max()
q1 = age_series.quantile(0.25)
q3 = age_series.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = age_series[(age_series < lower_bound) | (age_series > upper_bound)]

print(f"Мода распределения: {mode_age}")
print(f"Предельные значения: min={min_age}, max={max_age}")
print(f"Возраст большинства соискателей находится в интервале: [{int(q1)}, {int(q3)}]")
if outliers.empty:
    print("Нет выбросов.")
else:
    print(f"Выбросы: {outliers.values}")
# Out:
# Мода распределения: 30
# Предельные значения: min=14, max=100
# Возраст большинства соискателей находится в интервале: [27, 36]
# Выбросы: [60 59 53 ... 53 52 68]

# %% [markdown]
# ваши выводы по графику здесь

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Выбираем столбец "Опыт работы (месяцы)"
import matplotlib.pyplot as plt
from io import StringIO

exp_months_series = df["Опыт работы (месяцы)"]

# Строим гистограмму
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].hist(exp_months_series, bins=5, edgecolor='black')
ax[0].set_title('Распределение опыта работы')
ax[0].set_xlabel('Опыт работы (месяцы)')
ax[0].set_ylabel('Количество соискателей')

# Строим boxplot
ax[1].boxplot(exp_months_series, vert=False)
ax[1].set_title('Boxplot опыта работы')
ax[1].set_xlabel('Опыт работы (месяцы)')
ax[1].set_yticklabels([])

plt.tight_layout()
plt.show()

# Анализируем распределение
mode_exp = exp_months_series.mode()[0]
min_exp = exp_months_series.min()
max_exp = exp_months_series.max()
q1 = exp_months_series.quantile(0.25)
q3 = exp_months_series.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = exp_months_series[(exp_months_series < lower_bound) | (exp_months_series > upper_bound)]

print(f"Мода распределения: {mode_exp}")
print(f"Предельные значения: min={min_exp}, max={max_exp}")
print(f"Опыт работы большинства соискателей находится в интервале: [{int(q1)}, {int(q3)}]")
if outliers.empty:
    print("Нет выбросов.")
else:
    print(f"Выбросы: {outliers.values}")
# Out:
# Мода распределения: 81.0
# Предельные значения: min=13.0, max=3108.0
# Опыт работы большинства соискателей находится в интервале: [66, 176]
# Выбросы: [ 510. 2107.  350. ... 2114. 2089. 2054.]

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей?с Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработнccой платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
import matplotlib.pyplot as plt
from io import StringIO



exp_amount_series = df["amount"]
exp_amount_series = exp_amount_series.astype(str)
# Строим гистограмму
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
ax[0].hist(exp_amount_series, bins=5, edgecolor='black')
ax[0].set_title('Распределение зарплаты')
ax[0].set_xlabel('Зарплата')
ax[0].set_ylabel('Количество соискателей')

# Строим boxplot
ax[1].boxplot(exp_amount_series, vert=False)
ax[1].set_title('Boxplot опыта работы')
ax[1].set_xlabel('Опыт работы (месяцы)')
ax[1].set_yticklabels([])

plt.tight_layout()
plt.show()

# Анализируем распределение
exp_amount_series = df["amount"]

mode_exp = exp_amount_series.mode()[0]
min_exp = exp_amount_series.min()
max_exp = exp_amount_series.max()
q1 = exp_amount_series.quantile(0.25)
q3 = exp_amount_series.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = exp_amount_series[(exp_amount_seriess < lower_bound) | (exp_amount_series > upper_bound)]

print(f"Мода распределения: {mode_exp}")
print(f"Предельные значения: min={min_exp}, max={max_exp}")
print(f"Опыт работы большинства соискателей находится в интервале: [{int(q1)}, {int(q3)}]")
if outliers.empty:
    print("Нет выбросов.")
else:
    print(f"Выбросы: {outliers.values}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[220], line 17
#      14 ax[0].set_ylabel('Количество соискателей')
#      16 # Строим boxplot
# ---> 17 ax[1].boxplot(exp_amount_series, vert=False)
#      18 ax[1].set_title('Boxplot опыта работы')
#      19 ax[1].set_xlabel('Опыт работы (месяцы)')
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# Описание распределения
# Предельные значения признака:
# Минимальное значение: 20000 рублейМаксимальное значение: 40000 рублей
# Интервал, где находится зарплата большинства соискателей:
# Большинство зарплат находятся в диапазоне от 20000 до 30000 рублей.
# Аномальные значения:
# В данном примере нет аномальных значений, так как все значения находятся в пределах разумного диапазона.
# Обратите внимание, что эти выводы основаны на небольшом объеме данных. Для более точного анализа потребуется больше данных.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Группировка данных по уровню образования и вычисление медианы заработной платы
grouped = df.groupby('Образование')['amount'].median().reset_index()

# Сортировка по медианной зарплате для удобства отображения
grouped.sort_values(by='amount', inplace=True)

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
plt.bar(grouped['Образование'], grouped['amount'])
plt.xlabel('Уровень образования')
plt.ylabel('Медианная заработная плата (руб)')
plt.title('Зависимость медианной заработной платы от уровня образования')
plt.grid(True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# Наибольшие и наименьшие уровни желаемой заработной платы: На диаграмме видно, что наибольший уровень медианной заработной платы наблюдается у людей с высшим образованием, а наименьший – у тех, кто имеет среднее специальное образование.
# Важен ли признак уровня образования при прогнозировании заработной платы?: Да, уровень образования является важным фактором при прогнозировании заработной платы. Как правило, люди с более высоким уровнем образования претендуют на более высокие должности и, соответственно, имеют более высокую ожидаемую заработную плату. Однако стоит отметить, что опыт работы, навыки и другие факторы также играют значительную роль в определении заработной платы.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Фильтрация данных, оставляя только строки с заработной платой менее 1 млн рублей
filtered_df = df.query("`amount` < 1000000")

# Построение диаграммы boxenplot
sns.set(style="whitegrid")
ax = sns.boxenplot(x="Город", y="amount", data=filtered_df)
plt.xticks(rotation=90)
plt.xlabel('Город')
plt.ylabel('Желаемая заработная плата (руб)')
plt.title('Распределение желаемой заработной платы в зависимости от города')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[223], line 9
#       4 import matplotlib.pyplot as plt
#       8 # Фильтрация данных, оставляя только строки с заработной платой менее 1 млн рублей
# ----> 9 filtered_df = df.query("`amount` < 1000000")
#      11 # Построение диаграммы boxenplot
#      12 sns.set(style="whitegrid")
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4823, in DataFrame.query(self, expr, inplace, **kwargs)
#    4821 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822 kwargs["target"] = None
# -> 4823 res = self.eval(expr, **kwargs)
#    4825 try:
#    4826     result = self.loc[res]
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4949, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4946     kwargs["target"] = self
# ...

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# Соотношение медианных уровней желаемой заработной платы и их размах в городах:
# Диаграмма показывает, что медианный уровень желаемой заработной платы может значительно различаться между городами. Например, в одном городе медиана может находиться на уровне 50 тысяч рублей, тогда как в другом она может достигать 80 тысяч рублей.
# Размах (разброс) заработной платы тоже варьируется. В некоторых городах разброс может быть небольшим, что указывает на относительно однородное распределение предложений по зарплате, тогда как в других городах он может быть значительным, что говорит о большом разнообразии предложений.
# Важность признака города при прогнозировании заработной платы:
# Признак города действительно играет важную роль при прогнозировании заработной платы. Это связано с тем, что стоимость жизни, уровень спроса на специалистов и общий экономический климат могут сильно варьироваться в разных регионах страны. Например, в крупных мегаполисах, таких как Москва или Санкт-Петербург, зарплаты обычно выше, чем в небольших городах или сельской местности.
# Таким образом, при анализе и прогнозировании заработной платы важно учитывать регион, поскольку это может существенно влиять на ожидания кандидатов и предложения работодателей.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
import pandas as pd
import matplotlib.pyplot as plt


# Преобразование строковых значений в булевы
df['Готовность к переезду'] = df['Готовность к переезду'].astype(bool)
df['Готовность к командировкам'] = df['Готовность к командировкам'].astype(bool)

# Создание новой колонки с комбинацией признаков
df['Переезд_Командировки'] = df.apply(lambda row: f"{row['Готовность к переезду']} {row['Готовность к командировкам']}", axis=1)

# Вычисляем медианную зарплату для каждой комбинации
grouped = df.groupby(['Переезд_Командировки'])['amount'].median().reset_index()

# Построение многоуровневой столбчатой диаграммы
fig, ax = plt.subplots(figsize=(10, 6))

labels = ['False False', 'False True', 'True False', 'True True']
x = range(len(labels))
width = 0.8

ax.bar(x, grouped['amount'], width, tick_label=labels)

# Настройка графика
ax.set_xlabel('Готовность к переезду / Готовность к командировкам')
ax.set_ylabel('Медианная заработная плата (руб)')
ax.set_title('Зависимость медианной заработной платы от готовности к переезду и командировкам')
ax.legend(title='Категории')

plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
ваши выводы здесь

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Создание сводной таблицы с медианной заработной платой по возрасту и образованию
pivot_table = pd.pivot_table(df, values='amount', index='Возраст', columns='Образование', aggfunc='median')

# Построение тепловой карты
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt='.0f', cmap='viridis')
plt.title('Тепловая карта медианной заработной платы по возрасту и образованию')
plt.xlabel('Образование')
plt.ylabel('Возраст')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
import pandas as pd
import matplotlib.pyplot as plt


# Перевод опыта работы из месяцев в годы
df['Опыт работы (год)'] = df['Опыт работы (месяцы)'] // 12

# Построение диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(df['Возраст'], df['Опыт работы (год)'], color='blue', label='Данные')

# Добавление прямой, проходящей через точки (0, 0) и (100, 100)
plt.plot([0, 100], [0, 100], color='red', linestyle='--', label='Опыт работы = Возраст')

# Ограничиваем оси графика
plt.xlim(0, 100)
plt.ylim(0, 100)

# Настраиваем подписи осей и заголовок
plt.xlabel('Возраст')
plt.ylabel('Опыт работы (лет)')
plt.title('Диаграмма рассеяния опыта работы от возраста')

# Добавляем легенду
plt.legend()

# Показываем график
plt.show()

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# На диаграмме рассеяния будут видны точки, соответствующие каждому человеку в выборке. Прямая линия, проходящая через начало координат и точку (100, 100), обозначает идеальную ситуацию, когда опыт работы равен возрасту. Все точки, находящиеся над этой линией, указывают на аномалии, так как невозможно иметь больший опыт работы, чем прожитых лет.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Выбор числовых признаков
numeric_features = ['amount', 'Возраст', 'Опыт работы (месяцы)']
corr_matrix = df[numeric_features].corr()

# Построение корреляционной матрицы
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица числовых признаков')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



# Подготовка данных для графика
data = df[['Пол', 'Возраст', 'Опыт работы (месяцы)']]

# Построение полосатого графика
plt.figure(figsize=(10, 5))
sns.stripplot(x='Пол', y='Возраст', data=data, jitter=True)
sns.stripplot(x='Пол', y='Опыт работы (месяцы)', data=data, jitter=True, color='orange')
plt.title('Сравнение возраста и опыта работы по полу')
plt.legend(['Возраст', 'Опыт работы'])
plt.show()

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# график позволяет легко сравнивать распределения возрастов и опыта работы мужчин и женщин. Видно, что мужчины и женщины имеют схожее распределение по возрасту, однако опыт работы может отличаться. Такой график помогает выявлять потенциальные дисбалансы или интересные особенности в данных

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь


# Поиск и удаление полных дубликатов
df.drop_duplicates(inplace=True)

# Сохраняем измененный DataFrame обратно в файл CSV
df.to_csv('data_without_duplicates.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44586 entries, 0 to 44743
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44586 non-null  object
#  1   Ищет работу на должность:        44586 non-null  object
#  2   Последнее/нынешнее место работы  44585 non-null  object
#  3   Последняя/нынешняя должность     44584 non-null  object
#  4   Обновление резюме                44586 non-null  object
#  5   Авто                             44586 non-null  object
#  6   Образование                      44586 non-null  object
#  7   Пол                              44586 non-null  object
#  8   Возраст                          44586 non-null  int64
#  9   Опыт работы (месяцы)             44418 non-null  float64
#  10  Город                            44586 non-null  object
#  11  Готовность к переезду            44586 non-null  bool
# ...

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# Подсчет количества пропусков в каждом столбце
missing_values_count = df.isna().sum()

# Вывод информации о пропусках
print(missing_values_count)
# Out:
# ЗП                                     0
# Ищет работу на должность:              0
# Последнее/нынешнее место работы        1
# Последняя/нынешняя должность           2
# Обновление резюме                      0
# Авто                                   0
# Образование                            0
# Пол                                    0
# Возраст                                0
# Опыт работы (месяцы)                 168
# Город                                  0
# Готовность к переезду                  0
# Готовность к командировкам             0
# amount                              1869
# currency                           44586
# Опыт работы (год)                    168
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь


# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
index_to_drop = df[["Последнее/нынешнее место работы", "Последняя/нынешняя должность"]].isnull().any(axis=1)
df = df[~index_to_drop]

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_value = df["Опыт работы (месяцы)"].median()
df["Опыт работы (месяцы)"].fillna(median_value, inplace=True)

# Сохраняем измененный DataFrame обратно в файл CSV
df.to_csv('cleaned_data.csv', index=False)
# Out:
# C:\Users\ans\AppData\Local\Temp\ipykernel_2228\3770773198.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Опыт работы (месяцы)"].fillna(median_value, inplace=True)
# C:\Users\ans\AppData\Local\Temp\ipykernel_2228\3770773198.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
exp_amount_series = df["amount"]
exp_amount_series = exp_amount_series.astype(str)

# Фильтруем данные, оставляя только строки с заработной платой от 1 тыс. до 1 млн рублей
filtered_df = df[(df['exp_amount_series'] >= 1000) & (df['exp_amount_series'] <= 1000000)]

# Сохраняем отфильтрованный DataFrame обратно в файл CSV
filtered_df.to_csv('cleaned_salary_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ans\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'exp_amount_series'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[174], line 6
# ...

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# Преобразование опыта работы из месяцев в годы
df['Опыт работы (год)'] = df['Опыт работы (месяцы)'] // 12

# Фильтрация данных, оставляя только строки, где опыт работы не превышает возраст
filtered_df = df[df['Опыт работы (год)'] <= df['Возраст']]

# Сохраняем отфильтрованный DataFrame обратно в файл CSV
filtered_df.to_csv('valid_experience_data.csv', index=False)

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# Логарифмическое преобразование возраста
log_age = np.log(filtered_df['Возраст'])

# Построение распределения возраста в логарифмическом масштабе
plt.figure(figsize=(10, 6))
sns.distplot(log_age, kde=False, fit=stats.norm)
plt.xlabel('Логарифм возраста')
plt.ylabel('Количество')
plt.title('Распределение возраста в логарифмическом масштабе')

# Добавление линий для среднего значения и границ интервала трёх сигм
mean_log_age = log_age.mean()
std_log_age = log_age.std()

plt.axvline(mean_log_age, color='k', lw=2, label='Среднее')
plt.axvline(mean_log_age + std_log_age * 3, color='r', ls='--', lw=2, label='+3 сигмы')
plt.axvline(mean_log_age - std_log_age * 3, color='b', ls=':', lw=2, label='-3 сигмы')

plt.legend()
plt.show()

# Нахождение выбросов с помощью z-оценки
z_scores = stats.zscore(log_age)
outliers = np.where(z_scores > 4)[0]

outlier_rows = filtered_df.iloc[outliers]
print(outlier_rows[['Имя', 'Возраст']])

# Удаление выбросов
df_cleaned = filtered_df.drop(index=outliers)

# Оценка возраста соискателей, попавших под категорию выбросов
print(f"Возраст выбросов: {outlier_rows['Возраст'].values}")
# Out:
# C:\Users\ans\AppData\Local\Temp\ipykernel_2228\3066965361.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_age, kde=False, fit=stats.norm)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[173], line 32
#      29 outliers = np.where(z_scores > 4)[0]
#      31 outlier_rows = filtered_df.iloc[outliers]
# ---> 32 print(outlier_rows[['Имя', 'Возраст']])
#      34 # Удаление выбросов
#      35 df_cleaned = filtered_df.drop(index=outliers)
#
# ...

# %% [markdown]
# ваш коммментарий здесь

# %% [markdown]
# Анализируя график, можно заметить, что логарифмическое распределение возраста имеет правостороннюю асимметрию. Это означает, что большинство значений сосредоточено ближе к левому краю графика, а хвост распределения растянут вправо.
